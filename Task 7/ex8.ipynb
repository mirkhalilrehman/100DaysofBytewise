# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('titanic')


sns.set_palette('pastel')
sns.boxplot(x='class', y='fare', data=df)
plt.title('Customized Box Plot of Fares by Class')
plt.xlabel('Class')
plt.ylabel('Fare ($)')
plt.show()
